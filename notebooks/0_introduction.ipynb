# %% [markdown]
# # Künstliche Intelligenz - QR Code Klassifikation/Detektion in einer Waschstraße
#
# <img src="/Users/timschafer/Documents/Masterstudium/2. Semester/Künstliche Intelligenz/QR_Code_Windshield/qr-code-windshield-cnn/docs/LaTeX/Figures/png/example_fiat_dirty.png" alt="Fiat dirty" width="450">
# <img src="/Users/timschafer/Documents/Masterstudium/2. Semester/Künstliche Intelligenz/QR_Code_Windshield/qr-code-windshield-cnn/docs/LaTeX/Figures/png/example_mercedes_foam.png" alt="Mercedes foam" width="450">
#
# ## Gliederung
#
# 1. ROI $\rightarrow$ Patches, Extraktion mittels Computer Vision
# 2. QR-Code Klassifikation, eigene CNNs und Transferlearnings inkl. Auswertung
# 3. QR-Code Lokalisierung und Ausrichtung
